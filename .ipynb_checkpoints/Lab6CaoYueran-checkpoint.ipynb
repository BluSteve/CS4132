# %% [markdown]
# <P> <img src="https://i.ibb.co/gyNf19D/nhslogo.png" alt="nhslogo" border="0" width="100" align="right"><font size="6"><b> CS4132 Data Analytics</b> </font>

# %% [markdown]
# # Lab 6: Data Exploration I (Univariate Data)

# %% [markdown]
# Complete the following questions and upload your `.ipynb` file to Coursemology.
#
# Name the file in the following format:
#
# `Lab<Num><YourName>.ipynb`

# %% [markdown]
# ## Q1

# %% [markdown]
# The dataset below contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer. We will use this dataset for this lab.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Lab6Q1.csv', header=None, names=['Age', 'Operation_year', 'axil_codes_det', 'Surv_status'])
df
# Out:
#      Age  Operation_year  axil_codes_det  Surv_status
# 0     30              64               1            1
# 1     30              62               3            1
# 2     30              65               0            1
# 3     31              59               2            1
# 4     31              65               4            1
# 5     33              58              10            1
# 6     33              60               0            1
# 7     34              59               0            2
# 8     34              66               9            2
# 9     34              58              30            1
# 10    34              60               1            1
# 11    34              61              10            1
# 12    34              67               7            1
# 13    34              60               0            1
# 14    35              64              13            1
# 15    35              63               0            1
# 16    36              60               1            1
# 17    36              69               0            1
# 18    37              60               0            1
# 19    37              63               0            1
# 20    37              58               0            1
# 21    37              59               6            1
# 22    37              60              15            1
# 23    37              63               0            1
# 24    38              69              21            2
# 25    38              59               2            1
# 26    38              60               0            1
# 27    38              60               0            1
# 28    38              62               3            1
# 29    38              64               1            1
# ..   ...             ...             ...          ...
# 276   67              66               0            1
# 277   67              61               0            1
# 278   67              65               0            1
# 279   68              67               0            1
# 280   68              68               0            1
# 281   69              67               8            2
# 282   69              60               0            1
# 283   69              65               0            1
# 284   69              66               0            1
# 285   70              58               0            2
# 286   70              58               4            2
# 287   70              66              14            1
# 288   70              67               0            1
# 289   70              68               0            1
# 290   70              59               8            1
# 291   70              63               0            1
# 292   71              68               2            1
# 293   72              63               0            2
# 294   72              58               0            1
# 295   72              64               0            1
# 296   72              67               3            1
# 297   73              62               0            1
# 298   73              68               0            1
# 299   74              65               3            2
# 300   74              63               0            1
# 301   75              62               1            1
# 302   76              67               0            1
# 303   77              65               3            1
# 304   78              65               1            2
# 305   83              58               2            2
#
# [306 rows x 4 columns]

# %% [markdown]
# a) Display the statistics summary of the data.

# %%
#your solution
df.describe()
# Out:
#               Age  Operation_year  axil_codes_det  Surv_status
# count  306.000000      306.000000      306.000000   306.000000
# mean    52.457516       62.852941        4.026144     1.264706
# std     10.803452        3.249405        7.189654     0.441899
# min     30.000000       58.000000        0.000000     1.000000
# 25%     44.000000       60.000000        0.000000     1.000000
# 50%     52.000000       63.000000        1.000000     1.000000
# 75%     60.750000       65.750000        4.000000     2.000000
# max     83.000000       69.000000       52.000000     2.000000

# %%
#your solution
#Survival rate is less than half because the mean is 1.26, which is closer to 1 than 2.
#Also since the 50% percentile for surv-status is 1, the median is also 1, which means death.

# %% [markdown]
# Write down your observations below.

# %% [markdown]
# #### Key your answer here

# %% [markdown]
# b) Summarize the number of people who survived vs those who did not in a frequency table.
# Plot the data using a pie chart.

# %%
#your solution
freq = df.Surv_status.value_counts()
freq
# Out:
# 1    225
# 2     81
# Name: Surv_status, dtype: int64

# %%
#your solution
import matplotlib.pyplot as plt 
plt.pie(freq, labels=df.Surv_status.unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x27bc5660710>,
#   <matplotlib.patches.Wedge at 0x27bc5660c18>],
#  [Text(-0.7410651721946901, 0.8129098415937984, '1'),
#   Text(0.74106517219469, -0.8129098415937984, '2')])

# %% [markdown]
# c) We would like to see the distribution of the number of people who died based on the age. Plot a relevant graph for this.

# %%
#your solution
plt.hist((df[df.Surv_status == 2])['Age'], bins=10, ec='w')
plt.ylabel('Frequency')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# d) Draw a side by side boxplot of people who surived and those who died.

# %%
#your solution
plt.boxplot([df[df.Surv_status == 1]['Age'], df[df.Surv_status == 2]['Age']])
plt.ylabel('Age')
plt.xlabel('1: Survived, 2: Died')
# Out:
# Text(0.5, 0, '1: Survived, 2: Died')

# %% [markdown]
# State down your observations.

# %%
#The median age for both are around the same but number 2 has a distribution
#of ages that is higher. The ones who die are usually older. The min and max
#of ages are also higher for the graph of the ones who died.

# %% [markdown]
# e) Another common visualization similar to boxplot is the violin plot. Do a research on the violin plot and plot a violin plot similar to that in d). Explain how to read the violin plot and what insights it gives to the data.

# %%
#your solution
import seaborn as sb
sb.violinplot(df.Surv_status, df.Age)
#white dot is median
#thick bar indicates IQR
#thin lines indicate max and min
#The color around it indicates the distribution.
#it's like a boxplot but tells you the entire distribution

# %% [markdown]
# ## Q2

# %% [markdown]
# The data below shows the age of the US presidents at their inaugurations.

# %%
import pandas as pd
import numpy as np
df2 = pd.read_csv('Lab6Q2.csv')
df2
# Out:
#            President  Age
# 0        Washington    57
# 1          J. Adams    61
# 2         Jefferson    57
# 3           Madison    57
# 4            Monroe    58
# 5       J. Q. Adams    57
# 6           Jackson    61
# 7         Van Buren    54
# 8    W. H. Harrison    68
# 9             Tyler    51
# 10             Polk    49
# 11           Taylor    64
# 12         Fillmore    50
# 13           Pierce    48
# 14         Buchanan    65
# 15          Lincoln    52
# 16       A. Johnson    56
# 17            Grant    46
# 18            Hayes    54
# 19         Garfield    49
# 20           Arthur    50
# 21        Cleveland    47
# 22      B. Harrison    55
# 23        Cleveland    55
# 24         McKinley    54
# 25     T. Roosevelt    42
# 26             Taft    51
# 27           Wilson    56
# 28          Harding    55
# 29         Coolidge    51
# 30           Hoover    54
# 31  F. D. Roosevelt    51
# 32           Truman    60
# 33       Eisenhower    62
# 34          Kennedy    43
# 35    L. B. Johnson    55
# 36            Nixon    56
# 37             Ford    61
# 38           Carter    52
# 39           Reagan    69
# 40      G.H.W. Bush    64
# 41          Clinton    46
# 42       G. W. Bush    54
# 43  Barack H. Obama    47

# %% [markdown]
# a) Divide the range of the data into 6 classes of equal width. Count the number of observations in each class. To calculate the relative frequency, divide the frequency in each class by the total number of observations. You should store the data in a dataframe with 3 columns Class (i.e. interval), Frequency, Relative Frequency.
#
# Sample output:
# <table border="1" class="dataframe">
# <thead>
# <tr>
# <th></th>
# <th>Frequency</th>
# <th>Relative Frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>40 &ndash; 44</td>
# <td>2</td>
# <td>0.045455</td>
# </tr>
# <tr>
# <td>45 &ndash; 49</td>
# <td>7</td>
# <td>0.159091</td>
# </tr>
# </tbody>
# </table>

# %%
#your solution
import numpy as np
bins = [40,44.9,49.9,54.9,59.9,64.9,70]
a = pd.cut(df2['Age'], bins, labels=['40-44','45-49','50-54','55-59','60-64','65-69']
          )
a2 = a.value_counts()
table = pd.DataFrame(a2.sort_index())
table.columns=['Frequency'] #impt
table['Relative Frequency'] = table['Frequency'] / table['Frequency'].sum()
table
# Out:
#        Frequency  Relative Frequency
# 40-44          2            0.045455
# 45-49          7            0.159091
# 50-54         13            0.295455
# 55-59         12            0.272727
# 60-64          7            0.159091
# 65-69          3            0.068182

# %% [markdown]
# b) Plot a histogram with the class interval from (a)

# %%
#your solution
plt.hist(df2['Age'], bins, ec='w')
# Out:
# (array([ 2.,  7., 13., 12.,  7.,  3.]),
#  array([40. , 44.9, 49.9, 54.9, 59.9, 64.9, 70. ]),
#  <a list of 6 Patch objects>)

# %% [markdown]
# c) Add in two columns on Cumulative Frequency and Relative Cumulative Frequency into the frequency table.
#
# Sample output:
# <table border="1" class="dataframe">
# <thead>
# <tr>
# <th></th>
# <th>Frequency</th>
# <th>Relative Frequency</th>
# <th>Cumulative Frequency</th>
# <th>Relative Cumulative Frequency</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>40 &ndash; 44</td>
# <td>2</td>
# <td>0.045455</td>
# <td>2</td>
# <td>0.045455</td>
# </tr>
# <tr>
# <td>45 &ndash; 49</td>
# <td>7</td>
# <td>0.159091</td>
# <td>9</td>
# <td>0.204545</td>
# </tr>
# </tbody>
# </table>

# %%
#your solution
table['Cumulative Frequency'] = table['Frequency'].cumsum()
table['Relative Cumulative Frequency'] = table['Relative Frequency'].cumsum()
table
# Out:
#        Frequency  Relative Frequency  Cumulative Frequency  \
# 40-44          2            0.045455                     2
# 45-49          7            0.159091                     9
# 50-54         13            0.295455                    22
# 55-59         12            0.272727                    34
# 60-64          7            0.159091                    41
# 65-69          3            0.068182                    44
#
#        Relative Cumulative Frequency
# 40-44                       0.045455
# 45-49                       0.204545
# 50-54                       0.500000
# 55-59                       0.772727
# 60-64                       0.931818
# 65-69                       1.000000

# %% [markdown]
# d) Plot a cumulative frequency histogram below.

# %%
#your solution
plt.hist(df['Age'],bins,ec='w',cumulative=True)
# Out:
# (array([ 40.,  84., 140., 183., 218., 252.]),
#  array([40. , 44.9, 49.9, 54.9, 59.9, 64.9, 70. ]),
#  <a list of 6 Patch objects>)

# %% [markdown]
# e) Read up on <a href="https://cmdlinetips.com/2019/05/empirical-cumulative-distribution-function-ecdf-in-python/">Empirical cumulative distribution function (ECDF)</a> and plot a ECDF for the data given.
#
# Briefly explain your understanding of ECDF below.

# %%
#your solution
x = np.sort(df2['Age'])
n = x.size
y = np.arange(1, n+1) / n
plt.scatter(x,y)
plt.xlabel('Age')
plt.ylabel('RCF')
#The ECDF shows the probability that 
#a variable will take a value less than
#or equal to a specific value
# Out:
# Text(0, 0.5, 'RCF')

# %% [markdown]
# Answer the following question using the ECDF plotted.
# Was the US president, Barack Obama unusually young at age 47?

# %% [markdown]
# #### Key your answer here
# Yes, only around 8% of presidents are 47 or younger.
